# %% [markdown]
# <a href="https://colab.research.google.com/github/sathyaithazh555-creator/CODING-CHALLENGE-DAY-4/blob/main/Day_3_Retail_inventory_manager_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
product_categories = ('Electronics','stationary','clothing')
print("categories available=" ,(product_categories))
# Out:
# categories available= ('Electronics', 'stationary', 'clothing')

# %%
products_list =['Phone','laptop','book','pencil','pants','shirt']
print("Products_available=",(products_list))
# Out:
# Products_available= ['Phone', 'laptop', 'book', 'pencil', 'pants', 'shirt']

# %%
new_product = input("Enter a new product:")
products_list.append(new_product)
print("new_product_list:",products_list)
# Out:
# Enter a new product:Television
# new_product_list: ['Phone', 'laptop', 'book', 'pencil', 'pants', 'shirt', 'Television']

# %%
list(enumerate(products_list))
# Out:
# [(0, 'Phone'),
#  (1, 'laptop'),
#  (2, 'book'),
#  (3, 'pencil'),
#  (4, 'pants'),
#  (5, 'shirt'),
#  (6, 'Television')]

# %%
print("product list with index no:" '\n',list(enumerate(products_list)))
# Out:
# product list with index no:
#  [(0, 'Phone'), (1, 'laptop'), (2, 'book'), (3, 'pencil'), (4, 'pants'), (5, 'shirt'), (6, 'Television')]

# %%
remove_index = input("Enter the index of the product to remove:")
removed_product = products_list.pop(int(remove_index))
print("Removed product :",removed_product)
print("Final product list:",products_list)
print("Final categories available =",product_categories)
# Out:
# Enter the index of the product to remove:5
# Removed product : shirt
# Final product list: ['Phone', 'laptop', 'book', 'pencil', 'pants', 'Television']
# Final categories available = ('Electronics', 'stationary', 'clothing')
