# %% [markdown]
# <a href="https://colab.research.google.com/github/sathyaithazh555-creator/CODING-CHALLENGE-DAY-4/blob/main/Day_6_BMI_Calculatoripynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in m: "))
if weight <=0 or height <=0:
  print("weight and height must be in positive numbers!")
  BMI = weight/(height **2)

  if BMI <18.5:
    category = "underweight"
  elif 18.5<=BMI<24.9:
    catergory = "Normal weight"
  elif 25 <= BMI <29.9:
    category = "Over weight"
  else:
    category = "Obesity"
  print(f"\nYou BMI is :{BMI:.2f}")
  print("Health category:",category)
# Out:
# Enter your weight in kg: 0
# Enter your height in m: 1.5
# weight and height must be in positive numbers!
#
# You BMI is :0.00
# Health category: underweight
