# %% [markdown]
# <a href="https://colab.research.google.com/github/sathyaithazh555-creator/CODING-CHALLENGE-DAY-4/blob/main/Day_8_range%2Cfor_loop%2Cenumerate%2Clist_comprehension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
scores =[random.randint(0,100) for _ in range(10)]
print("exam scores:",scores)
print("\n scores with index:")
for index,score in enumerate(scores):
  print(f"index{index}:score={score}")
  high_scores=[score for score in scores if score>80]
  print("\n scores greater than 80:",high_scores)
  average_score =sum(scores)/len(scores)
  print(f"\nAverage score:{average_score:.2f}")
# Out:
# exam scores: [25, 50, 10, 0, 13, 91, 74, 93, 85, 76]
#
#  scores with index:
# index0:score=25
#
#  scores greater than 80: [91, 93, 85]
#
# Average score:51.70
# index1:score=50
#
#  scores greater than 80: [91, 93, 85]
#
# Average score:51.70
# index2:score=10
#
#  scores greater than 80: [91, 93, 85]
#
# Average score:51.70
# index3:score=0
#
#  scores greater than 80: [91, 93, 85]
#
# Average score:51.70
# index4:score=13
#
#  scores greater than 80: [91, 93, 85]
#
# Average score:51.70
# index5:score=91
#
#  scores greater than 80: [91, 93, 85]
#
# Average score:51.70
# index6:score=74
#
#  scores greater than 80: [91, 93, 85]
#
# Average score:51.70
# index7:score=93
#
#  scores greater than 80: [91, 93, 85]
#
# Average score:51.70
# index8:score=85
#
#  scores greater than 80: [91, 93, 85]
#
# Average score:51.70
# index9:score=76
#
#  scores greater than 80: [91, 93, 85]
#
# Average score:51.70
