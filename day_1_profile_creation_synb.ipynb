# %% [markdown]
# <a href="https://colab.research.google.com/github/sathyaithazh555-creator/CODING-CHALLENGE-DAY-4/blob/main/day_1_profile_creation_synb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### store student details
student_name = "madhu"
student_age =12
favourite_subjects = ["maths","physics","chemistry"]

# %%
print(student_name)
print(student_age)
print(favourite_subjects)
# Out:
# madhu
# 12
# ['maths', 'physics', 'chemistry']

# %%
new_favourite_subject = input("Enter your favourite subject")
print(new_favourite_subject)
# Out:
# Enter your favourite subjectbiology
# biology

# %%
##### adding new favourite subject with favourite subjects

# %%
favourite_subjects.append(new_favourite_subject)
print(favourite_subjects)
# Out:
# ['maths', 'physics', 'chemistry', 'biology']

# %%
print(favourite_subjects)
# Out:
# ['maths', 'physics', 'chemistry', 'biology']
