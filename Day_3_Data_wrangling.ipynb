# %% [markdown]
# <a href="https://colab.research.google.com/github/sathyaithazh555-creator/CODING-CHALLENGE-DAY-4/blob/main/Day_3_Data_wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?export=download&id=1GJwDieiqffFzEZtZ3XXVd3jXylHnzFba")

print("=== 🔍 DATA EXPLORATION STARTED ===\n")

# 1️⃣ Explore dataset
print("\n--- HEAD (First 5 rows) ---")
print(df.head())

print("\n--- TAIL (Last 5 rows) ---")
print(df.tail())

print("\n--- INFO (Data types + null count) ---")
print(df.info())

print("\n--- DESCRIBE (Statistics) ---")
print(df.describe())

print("\n--- VALUE COUNTS (Attrition) ---")
print(df["Attrition"].value_counts())

# 2️⃣ Detect & handle missing values
print("\n--- MISSING VALUES COUNT ---")
print(df.isna().sum())

# Fill NA — example: MonthlyIncome
df["MonthlyIncome"] = df["MonthlyIncome"].fillna(df["MonthlyIncome"].median())

# Drop NA rows (copy for demo)
df_no_na = df.dropna()

print("\nMissing values handled successfully ✔️")

# 3️⃣ Merge / Concat / Join demo

# Create sample dataframe for merge
department_df = df[["Department"]].reset_index()
# Out:
# === 🔍 DATA EXPLORATION STARTED ===
#
#
# --- HEAD (First 5 rows) ---
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...
