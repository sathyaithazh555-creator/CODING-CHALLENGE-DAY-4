# %% [markdown]
# <a href="https://colab.research.google.com/github/sathyaithazh555-creator/CODING-CHALLENGE-DAY-4/blob/main/Day_5_Seaborn%2Cplotly_visualization1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as plt
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np
df = pd.read_csv("https://drive.google.com/uc?export=download&id=1GJwDieiqffFzEZtZ3XXVd3jXylHnzFba")

# %%
import matplotlib.pyplot as plt
####Heatmap
plt.figure(figsize=(8,5))
numeric_column=df.select_dtypes(include=[np.number])
corr=numeric_column.corr()
sns.heatmap(corr,cmap = "coolwarm",annot=False)
plt.title("correlation heatmap(Numeric features)")
plt.show()

# %%
####Pairplot
g = sns.pairplot(df[["Age","MonthlyIncome","JobSatisfaction","YearsAtCompany"]])
g.fig.suptitle("pairplot of selected features",y=1.02)
plt.show()

# %%
###Violin plot
plt.figure(figsize=(8,5))
sns.violinplot(data=df,x="Attrition",y="MonthlyIncome")
plt.title("Violin plot: MonthlyIncome by Attrition")
plt.show()

# %%
####Swarm plot
plt.figure(figsize=(8,5))
sns.stripplot(data=df,x="Attrition",y="JobSatisfaction") # Changed to stripplot
plt.title("Strip plot:JobSatisfaction by Attrition")
plt.show()

# %%
####Scatter plot
fig_scatter = px.scatter(
    df,x="Age",y="MonthlyIncome",color="Attrition",title="Age v/s MonthlyIncome"
)
fig_scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
####Bar plot
dept_income = df.groupby("Department")["MonthlyIncome"].mean().reset_index()
fig_bar = px.bar(
    dept_income,x="Department",y="MonthlyIncome",title="Avg_monthly_income by department"
)
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
####Line chart
Years_income = df.groupby("YearsAtCompany")["MonthlyIncome"].mean().reset_index()
fig_line = px.line(
    Years_income,x= "YearsAtCompany",y="MonthlyIncome",
    title="Avg monthly income v/s yearsAtCompany"
)
fig_line.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
