# %% [markdown]
# <a href="https://colab.research.google.com/github/sathyaithazh555-creator/CODING-CHALLENGE-DAY-4/blob/main/Day_7_While_loop%2Celse%2Cbreak%2Ccontinue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
secret_number = random.randint(1,20)
print("Welcome to the number guessing game!")
secret_number =10
attempts=0
max_attempts=5
while attempts < max_attempts:
  try:
    guess =int(input(f"\n Attempt{attempts +1}/5-enter your guess(1-20):"))
  except ValueError:
    print("invalid input! Please enter a valid number.")
    continue
  attempts+=1
  if guess < secret_number:
    print("Too low! try again")
  elif guess > secret_number:
    print("Too high! try again")
  else:
    print(f"\n Correct! The number was {secret_number}. You guessed it in {attempts} attempts!")
    break
else:
  print(f"\n You have used all {max_attempts} attempts. The secret number is {secret_number}.")
# Out:
# Welcome to the number guessing game!
#
#  Attempt1/5-enter your guess(1-20):5
# Too low! try again
#
#  Attempt2/5-enter your guess(1-20):7
# Too low! try again
#
#  Attempt3/5-enter your guess(1-20):15
# Too high! try again
#
#  Attempt4/5-enter your guess(1-20):12
# Too high! try again
#
#  Attempt5/5-enter your guess(1-20):10
#
#  Correct! The number was 10. You guessed it in 5 attempts!
