# %% [markdown]
# <a href="https://colab.research.google.com/github/sathyaithazh555-creator/CODING-CHALLENGE-DAY-4/blob/main/Day_5_dic%2Cset%2Cfrozenset1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
grades = {
    "Madhu":78,
    "kalai":90,
    "susi":97
}
print("Initial grades:",grades)
# Out:
# Initial grades: {'Madhu': 78, 'kalai': 90, 'susi': 97}

# %%
print("\nupdate grades for 3 students")
for i in range(3):
    name= input(f"Enter student name{i+1}: ")
    grade=int(input(f"Enter grade for {name}: "))
    grades[name] =grade
    print(f"grade updated for {name} ")
print("\nFinal grades dictionary:", grades)
# Out:
# update grades for 3 students
# Enter student name1: Sudha
# Enter grade for Sudha: 98
# grade updated for Sudha
# Enter student name2: Vinitha
# Enter grade for Vinitha: 87
# grade updated for Vinitha
# Enter student name3: Ashok
# Enter grade for Ashok: 67
# grade updated for Ashok
#
# Final grades dictionary: {'Madhu': 78, 'kalai': 90, 'susi': 97, 'sudha': 87, 'vinitha': 78, 'Sudha': 98, 'Vinitha': 87, 'Ashok': 67}

# %%
hobbies = set()
print("\n Enter atleast 3 hobbies")
for i in range(3):
  hobby = input(f"Enter hobby{i+1}: ")
  hobbies.add(hobby)
  print("\nhobbies set:",hobbies)
# Out:
#  Enter atleast 3 hobbies
# Enter hobby1: drawing
#
# hobbies set: {'drawing'}
# Enter hobby2: singing
#
# hobbies set: {'drawing', 'singing'}
# Enter hobby3: playing music
#
# hobbies set: {'drawing', 'singing', 'playing music'}

# %%
hobby_frozenset = frozenset(hobbies)
print("\nhobbies frozenset(immutable):",hobby_frozenset)
# Out:
# hobbies frozenset(immutable): frozenset({'drawing', 'singing', 'playing music'})
